# %%
result = ''
string = 'ABCD'

stack =[]

# %%
for i in (string):
    stack.append(i)

# %%
for i in range (len(stack)):
    ans = stack.pop()
    result = result + str(ans)

# %%
result
# Out:
# 'DCBA'

# %% [markdown]
# # Q2

# %%
arr = [6,8,0,1,3]
stack1=[]
final=[]

# %%
for i in range(len(arr)-1,-1,-1):
    arr[i] <
# Out:
# 3
# 1
# 0
# 8
# 6

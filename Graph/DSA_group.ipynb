# %%
adj = {
    0:[1,2,3],
    1:[0,3],
    2:[0,4],
    3:[0,1,4],
    4:[2,3,5],
    5:[4]
}

# %%
Visited = set()

# %%
def DFS(node):
    if node in Visited:
        return
    Visited.add(node)
    print(node)

    for neberihods in  adj[node]:
        DFS(neberihods)

# %%
DFS(0)

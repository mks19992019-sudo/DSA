# %%
arr = [3,4,6,8,1]

# %%
arr.index(65)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 arr.index(65
#       2           )
#
# ValueError: list.index(x): x not in list

# %%
e= arr.pop()

# %%
e
# Out:
# 1

# %%
a =3 in arr
# Out:
# True

# %%
print(idx,a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(idx,a)
#
# NameError: name 'idx' is not defined

# %%
arr.sort(reverse=True)

# %%
arr
# Out:
# [8, 6, 4, 3]

# %%
for i , num in enumerate(arr):
    print(f'{i}:{num}')
# Out:
# 0:8
# 1:6
# 2:4
# 3:3

# %%
matruix = [[
    1,3,4
],
[3,5,6]]

# %%
matruix
# Out:
# [[1, 3, 4], [3, 5, 6]]

# %%
for raw in matruix:
    for element in raw:
        print(element, end=' ')
    print()
# Out:
# 1 3 4
# 3 5 6

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

# %%
class linklist:
    def __init__(self):
        self.head = None

    def insert_head(self,data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def insert_last(self,data):
        new_node = Node(data)
        if self.head == None:
            return 'empty list'
        temp = self.head 
        while temp.next !=None:
            temp = temp.next
        temp.next = new_node
        return
    
    def remove(self,target):
        if self.head == None:
            return 'empty'
        if self.head.data == target:
            self.head = self.head.next
            return 
        temp = self.head
        while temp.next !=None:
            if temp.next.data == target:
                break
            temp = temp.next
        if temp.next == None:
            return 'elemnt not found'
        else:
            temp.next = temp.next.next

# %%
a = linklist()

# %%
a.insert_head(4)

# %%
a.insert_head(46)
a.insert_head(47)
a.insert_head(43)

# %%
a.remove(43)
# Out:
# 'elemnt not found'

# %%
def remove(self,target):
        if self.head == None:
            return 'empty list'
        if self.head.val == target:
            return self.delete_head()
        
        temp = self.head
        while temp.next != None:
            if temp.next.val == target:
                break
            temp = temp.next
        
        if temp.next == None:
             return ' elemnt not found'
        else:
             temp.next = temp.next.next

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

# %%
class circular:
    def __init__(self):
        self.head = None
    def inser_beg(self,data):
        new_node = Node(data)
        if self.head ==None:
            self.head = new_node
            new_node.next = self.head
            return
        temp = self.head 
        while temp.next != self.head:
            temp = temp.next

        temp.next = new_node
        new_node.next = self.head
        self.head = new_node
        return
    
    def insert_last(self,data):
        new_node = Node(data)
        if self.head ==None:
            self.head = new_node
            new_node.next = self.head
        
        temp = self.head

        while temp.next != self.head:
            temp = temp.next
        temp.next = new_node
        new_node.next = self.head

    
    def display(self):
        if self.head == None:
            return 'empty'
        temp = self.head

        while True:
            print(temp.data , end='->')
            temp = temp.next

            
            if temp == self.head:
                break
        print('back to head')


    def head_remove(self):
        if self.head == None:
            return 'empty'
        
        if self.head.next == self.head:
            self.head = None
            return
        
        temp = self.head

        while temp.next !=self.head:
            temp = temp.next

        self.head = self.head.next
        temp.next = self.head

    def remove_last(self):
        if self.head == None:
            return 'empty'
        
        if self.head.next == self.head:
            self.head = None
            return
        
        temp = self.head

        while temp.next.next != self.head:
            temp = temp.next

        temp.next = self.head


    def count(self):
        if self.head == None:
            return 0
        count = 0
        temp = self.head
        while True:
            count +=1
            temp = temp.next
            if temp == self.head:
                break
        return count

    def serch(self,value):
        if self.head == None:
            return 'empty'

        temp = self.head
        count = 0

        while True:
            
            if temp.data == value:
                return (f'found at {count}')
            

            temp = temp.next
            count +=1
            if temp == self.head:
                return 'not found'

# %%
circular = circular()

# %%
circular.inser_beg(4)

# %%
circular.inser_beg(1)
circular.inser_beg(6)
circular.inser_beg(9)

# %%
circular.display()
# Out:
# 9->6->1->4->back to head

# %%
circular.serch(9)
# Out:
# 'found at 0'

# %%
circular.insert_last(44)

# %%
circular.count()
# Out:
# 4

# %%
circular.remove_last()
# Out:
# 'empty'

# %%
circular.head_remove()
# Out:
# 'empty'

# %% [markdown]
# # stack

# %%
class Stack:
    def __init__(self):
        self.list = []
    def push(self,data):
        self.list.append(data)
    def pop(self):
        if len(self.list) == 0:
            return 'empty'
        self.list.pop()
    
    def peek(self):
        return self.list[-1]
    def is_empty(self):
        return len(self.list) == 0
    def size(self):
        return len(self.list)
    
    def show(self):
        return (self.list)

# %%
st = Stack()

# %%
st.push(8)
st.push(6)
st.push(1)
st.push(5)

# %%
st.show()
# Out:
# [8]

# %%
st.pop()

# %%
st.peek()
# Out:
# 5

# %%
st.size()
# Out:
# 4

# %%
st.is_empty()
# Out:
# False

# %%
def is_balanced(expersion):
    stack = Stack()
    matching = { ')': '(' ,
                 '}': '{',
                   ']': '['
                   }
    for ch in expersion:
        if ch in '({[':
            stack.push(ch)
        elif ch in ')}]':
            if stack.is_empty():
                return False
            top = stack.pop()
            if top != matching[ch]:
                return False
    
    return stack.is_empty()

# %%
def is_balnced(expe):
    stack = Stack()
    matching = {
        ')' : '(',
        '}':'{',
        ']':'['

    }

    for c in expe:
        if c in '({[':
            stack.push(c)
        elif c in ')}]':
            if stack.is_empty():
                return 'not in sequnce'
            top = stack.pop()
            if top != matching[c]:
                return 'not match in sequnce'
    return stack.is_empty()

# %%
{[()]}

{[(

# %%
class Stack:
    # self

# %% [markdown]
# # queue

# %%
from collections import deque

# %%
class queue:
    def __init__(self):
        self.queu = deque()
    def enqueu (self,data):
        self.queu.append(data)
    
    def dequeue(self):
        if self.is_empty():
            return 'empty '
        
        self.queu.popleft()

    def front(self):
        if self.is_empty():
            return 'empty'
        return self.queu[0]
    
    
    def is_empty(self):
        return  len(self.queu) == 0
    
    def size(self):
        return len(self.queu)
    
    def diplay(self):
        if self.is_empty():
            return 'empty'

        print ('Front -> ', list(self.queu), '<- rear')

# %%
c= queue()

# %%
c.enqueu(5)

# %%
c.enqueu(5)
c.enqueu(6)
c.enqueu(8)

# %%
c.diplay()
# Out:
# 'empty'

# %%
c.dequeue()
# Out:
# 'empty '

# %% [markdown]
# # using linklist

# %%
class Node:
    def __init__self(data):
        self.data = data
        self.next = None

# %%
class queue:
    def __init__(self):
        self.front = None
        self.rear = None
    
    def enqueue(self,data):
        if self.

# %%
class Node:
    def __init__(self,val):

        self.val = val
        self.left = None
        self.right = None

# %%
# Nodes

node_1 = Node(1)

node_2 = Node(2)

node_3 = Node(3)

node_4 = Node(4)

node_5 = Node(5)

# Connections

node_1.left = node_2

node_1.right = node_3

node_2.left = node_4

node_2.right = node_5

# %%
node_1.val
# Out:
# 1

# %%
# pre order (root,left,right)
def pre_order(node):
    if node == None:
        return
    print(node.val , end=" ")
    pre_order(node.left)
    pre_order(node.right)

# %%
pre_order(node_1)
# Out:
# 1 2 4 5 3

# %%
def in_order(data):
    if data == None:
        return
    in_order(data.left)
    print(data.val, end = ' ')
    in_order(data.right)

# %%
in_order(node_1)
# Out:
# 4 2 5 1 3

# %%
def post_order(data):
    if data == None:
        return
    post_order(data.left)
    
    post_order(data.right)
    print(data.val, end = ' ')

# %%
post_order(node_1)
# Out:
# 4 5 2 3 1

# %%
#bfs

from collections import deque

# %%
def BFS(node):
    result = []
    queue = deque()
    queue.append(node)
    while len(queue) != 0:
        e = queue.popleft()
        result.append(e.val)
        if e.left != None:
            queue.append(e.left)
        if e.right != None:
            queue.append(e.right)
    return result

# %%
BFS(node_1)
# Out:
# [1, 2, 3, 4, 5]

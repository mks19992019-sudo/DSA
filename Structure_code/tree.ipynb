# %% [markdown]
# # different traversal in a binary tree

# %% [markdown]
# 1. DFS (Depth First Search) Traversal:
#    - Inorder Traversal: Left, Root, Right
#    - Preorder Traversal: Root, Left, Right
#    - Postorder Traversal: Left, Right, Root
#
# 2. BFS (Breadth First Search) Traversal:
#     - Level Order Traversal: Traverse the tree level by level from left to right.

# %% [markdown]
# ### hack for order of traversal
#
# - inorder mean root in middle
# - preorder mean root in first
# - postorder mean root in last

# %%
class Node:
    def __init__(self,data):
        self.val = data
        self.left = None
        self.right = None

# %%
# random tree making 
node1 = Node(1)
node2 = Node(2)
node3 = Node(3)
node4 = Node(4)
node5 = Node(5)
node6 = Node(6)
node7 = Node(7)


node1.left = node2
node1.right = node3
node2.left = node4
node2.right = node5
node3.left = node6
node3.right = node7

# %% [markdown]
# veiw of tree
#
#          1
#        /   \
#       2     3
#      / \   / \
#     4   5 6   7

# %%
def inorder_traversal(root):
    if root is None:
        return
    # print the value of the current node
    print(root.val , end=' ')

    # Traverse the left subtree
    inorder_traversal(root.left)

    # Traverse the right subtree
    inorder_traversal(root.right)

# %%
inorder_traversal(node1)
# Out:
# 1 2 4 5 3 6 7

# %%
def inorder_traversal(root):
    if root is None:
        return
    

    inorder_traversal(root.left)
    print(root.val , end=' ')
    inorder_traversal(root.right)

# %%
inorder_traversal(node1)
# Out:
# 4 2 5 1 6 3 7

# %%
def postorder_traversal(root):
    if root is None:
        return
    
    postorder_traversal(root.left)
    postorder_traversal(root.right)
    print(root.val , end=' ')

# %%
postorder_traversal(node1)
# Out:
# 4 5 2 6 7 3 1

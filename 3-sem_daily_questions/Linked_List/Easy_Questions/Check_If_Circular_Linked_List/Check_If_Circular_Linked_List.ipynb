# %%
#class Node:
#    def __init__(self, data):
#        self.data = data
#        self.next = None


class Solution:
    def isCircular(self, head):
        # code here
        
        temp = head
        result = False
        
        while True:
            temp = temp.next
            if temp == None:
                break
            if temp == head:
                return True
        return False
